# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
engine.execute('SELECT * FROM Station LIMIT 5').fetchall()
engine.execute('SELECT * FROM Measurement LIMIT 5').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0)]

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
recent_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(recent_date)
# Calculate the date one year from the last date in data set.
one_year_ago = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(one_year_ago)

# Perform a query to retrieve the data and precipitation scores
prcp_data = session.query(Measurement.date, Measurement.prcp).\
    filter(Measurement.date > one_year_ago).\
    order_by(Measurement.date).all()


# Save the query results as a Pandas DataFrame and set the index to the date column
prcp_data_df = pd.DataFrame(prcp_data)
prcp_data_df.head()

# Sort the dataframe by date
#figure out how

# Use Pandas Plotting with Matplotlib to plot the data
ax = prcp_data_df.plot(figsize=(8,4))
ax.set_title("Precipitation Analysis (8/24/16 to 8/23/17)")
ax.set_ylabel('frequency')
plt.show()
# Out:
# ('2017-08-23',)
# 2016-08-23

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcp_data_df.describe()
# Out:
#                  1
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
locations = session.query(Measurement).group_by(Measurement.station).count()
print("There are {} stations available.".format(locations))
# Out:
# There are 9 stations available.

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
most_active = session.query(Measurement.station, 
                                    func.count(Measurement.station).\
                                    label('count')).\
                                    group_by(Measurement.station).\
                                    order_by('count DESC').limit(1)[0][0]
most_active
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in visit_textual_label_reference(self, element, within_columns_clause, **kwargs)
#    1367             else:
# -> 1368                 col = with_cols[element.element]
#    1369         except KeyError as err:
#
# KeyError: 'count DESC'
#
# The above exception was the direct cause of the following exception:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-37-ebeffac6448b> in <module>
#       5                                     label('count')).\
#       6                                     group_by(Measurement.station).\
# ----> 7                                     order_by('count DESC').limit(1)[0][0]
#       8 most_active
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __getitem__(self, item)
#    2597             self,
#    2598             item,
# -> 2599             allow_negative=not self.session or not self.session.future,
#    2600         )
#    2601
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/util.py in _getitem(iterable_query, item, allow_negative)
#    1988             return list(iterable_query)[-1]
#    1989         else:
# -> 1990             return list(iterable_query[item : item + 1])[0]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __getitem__(self, item)
#    2597             self,
#    2598             item,
# -> 2599             allow_negative=not self.session or not self.session.future,
#    2600         )
#    2601
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/util.py in _getitem(iterable_query, item, allow_negative)
#    1982             return list(res)[None : None : item.step]
#    1983         else:
# -> 1984             return list(res)
#    1985     else:
#    1986         if item == -1:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __iter__(self)
#    2838
#    2839     def __iter__(self):
# -> 2840         return self._iter().__iter__()
#    2841
#    2842     def _iter(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _iter(self)
#    2848             statement,
#    2849             params,
# -> 2850             execution_options={"_sa_orm_load_options": self.load_options},
#    2851         )
#    2852
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/orm/session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1687         else:
#    1688             conn = self._connection_for_bind(bind)
# -> 1689         result = conn._execute_20(statement, params or {}, execution_options)
#    1690
#    1691         if compile_state_cls:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_20(self, statement, parameters, execution_options)
#    1581             )
#    1582         else:
# -> 1583             return meth(self, args_10style, kwargs_10style, execution_options)
#    1584
#    1585     def exec_driver_sql(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     322         if _force or self.supports_execution:
#     323             return connection._execute_clauseelement(
# --> 324                 self, multiparams, params, execution_options
#     325             )
#     326         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1448             for_executemany=for_executemany,
#    1449             schema_translate_map=schema_translate_map,
# -> 1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
#    1452         ret = self._execute_context(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     522                     for_executemany=for_executemany,
#     523                     schema_translate_map=schema_translate_map,
# --> 524                     **kw
#     525                 )
#     526                 compiled_cache[key] = compiled_sql
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _compiler(self, dialect, **kw)
#     551         Dialect."""
#     552
# --> 553         return dialect.statement_compiler(dialect, self, **kw)
#     554
#     555     def __str__(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in __init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, **kwargs)
#     763         self.truncated_names = {}
#     764
# --> 765         Compiled.__init__(self, dialect, statement, **kwargs)
#     766
#     767         if self.isinsert or self.isupdate or self.isdelete:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in __init__(self, dialect, statement, schema_translate_map, render_schema_translate, compile_kwargs)
#     452             if self.can_execute:
#     453                 self.execution_options = statement._execution_options
# --> 454             self.string = self.process(self.statement, **compile_kwargs)
#     455
#     456             if render_schema_translate:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in process(self, obj, **kwargs)
#     487
#     488     def process(self, obj, **kwargs):
# --> 489         return obj._compiler_dispatch(self, **kwargs)
#     490
#     491     def __str__(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#      84     cls._compiler_dispatch = (
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in visit_select(self, select_stmt, asfrom, fromhints, compound_index, select_wraps_for, lateral, from_linter, **kwargs)
#    3237             byfrom,
#    3238             toplevel,
# -> 3239             kwargs,
#    3240         )
#    3241
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in _compose_select_body(self, text, select, compile_state, inner_columns, froms, byfrom, toplevel, kwargs)
#    3402
#    3403         if select._order_by_clauses:
# -> 3404             text += self.order_by_clause(select, **kwargs)
#    3405
#    3406         if select._has_row_limiting_clause:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in order_by_clause(self, select, **kw)
#    3470
#    3471         order_by = self._generate_delimited_list(
# -> 3472             select._order_by_clauses, OPERATORS[operators.comma_op], **kw
#    3473         )
#    3474
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in _generate_delimited_list(self, elements, separator, **kw)
#    1591         return separator.join(
#    1592             s
# -> 1593             for s in (c._compiler_dispatch(self, **kw) for c in elements)
#    1594             if s
#    1595         )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in <genexpr>(.0)
#    1590     def _generate_delimited_list(self, elements, separator, **kw):
#    1591         return separator.join(
# -> 1592             s
#    1593             for s in (c._compiler_dispatch(self, **kw) for c in elements)
#    1594             if s
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in <genexpr>(.0)
#    1591         return separator.join(
#    1592             s
# -> 1593             for s in (c._compiler_dispatch(self, **kw) for c in elements)
#    1594             if s
#    1595         )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#      84     cls._compiler_dispatch = (
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in visit_textual_label_reference(self, element, within_columns_clause, **kwargs)
#    1375                 ),
#    1376                 exc_cls=exc.CompileError,
# -> 1377                 err=err,
#    1378             )
#    1379         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/coercions.py in _no_text_coercion(element, argname, exc_cls, extra, err)
#     356             }
#     357         ),
# --> 358         replace_context=err,
#     359     )
#     360
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# CompileError: Can't resolve label reference for ORDER BY / GROUP BY / DISTINCT etc. Textual SQL expression 'count DESC' should be explicitly declared as text('count DESC')

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
temp = [func.min(Measurement.tobs),
       func.max(Measurement.tobs),
       func.avg(Measurement.tobs)]
session.query(*temp).filter(Measurement.station==most_active).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-6aa3f7cec383> in <module>
#       3        func.max(Measurement.tobs),
#       4        func.avg(Measurement.tobs)]
# ----> 5 session.query(*temp).filter(Measurement.station==most_active).all()
#
# NameError: name 'most_active' is not defined

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
